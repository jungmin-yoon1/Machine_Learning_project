# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn import svm
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Linear SVM

# %%
#데이터 불러오기
X_1 = pd.read_csv('/content/drive/MyDrive/hw2_data-1/hw2_2_X_1.csv', encoding='utf-8')
y_1 = pd.read_csv('/content/drive/MyDrive/hw2_data-1/hw2_2_y_1.csv', encoding='utf-8')

# %%
X_1.head()
# Out:
#    1.41281595  1.5303347
# 0    1.813361   1.631131
# 1    1.432893   4.376792
# 2    1.872718   4.180692
# 3    2.095178   1.079147
# 4    2.738908   0.156768

# %%
y_1.head()
# Out:
#    1
# 0  1
# 1  0
# 2  0
# 3  1
# 4  1

# %%
#linear SVM
clf_1 = svm.SVC(kernel='linear')
clf_1.fit(X_1, y_1)

#plot the data
res_1 = pd.concat([X_1, y_1], axis=1) 
plt.scatter(res_1.iloc[:, 0],res_1.iloc[:, 1],c=res_1.iloc[:,2], s=30,cmap=plt.cm.Paired)

#초평면(Hyper-Plane) 표현
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf_1.decision_function(xy).reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1], alpha=0.5, linestyles=['--', '-', '--'])

# Support Vector 표현
ax.scatter(clf_1.support_vectors_[:,0], clf_1.support_vectors_[:,1], s=100, linewidth=2, facecolors='none', edgecolors='k')

plt.xlabel('X_1[:,0]')
plt.ylabel('X_1[:,1]')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"

# %% [markdown]
# # RBF SVM

# %%
#데이터 불러오기
X_2 = pd.read_csv('/content/drive/MyDrive/hw2_data-1/hw2_2_X_2.csv', encoding='utf-8')
y_2 = pd.read_csv('/content/drive/MyDrive/hw2_data-1/hw2_2_y_2.csv', encoding='utf-8')

# %%
X_2.head()
# Out:
#    -3.33376840e-01  -1.06756249e+00
# 0        -0.913105         0.227597
# 1        -0.895422        -0.119601
# 2         0.071089        -0.094316
# 3         0.005954         0.081674
# 4         0.076016         0.007531

# %%
y_2.head()
# Out:
#    -1
# 0  -1
# 1  -1
# 2   1
# 3   1
# 4   1

# %%
# RBF kernel SVM
clf_2 = svm.SVC(kernel='rbf')
clf_2.fit(X_2, y_2)

#plot the data
res_2 = pd.concat([X_2, y_2], axis=1)
plt.scatter(res_2.iloc[:, 0],res_2.iloc[:, 1],c=res_2.iloc[:,2], s=30,cmap=plt.cm.Paired)

#초평면(Hyper-Plane) 표현
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf_2.decision_function(xy).reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1], alpha=0.5, linestyles=['--', '-', '--'])

# Support Vector 표현
ax.scatter(clf_2.support_vectors_[:,0], clf_2.support_vectors_[:,1], s=100, linewidth=2, facecolors='none', edgecolors='k')

plt.xlabel('X_2[:,0]')
plt.ylabel('X_2[:,1]')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"

# %% [markdown]
# # Linear SVM with Soft margin

# %%
#데이터 불러오기
X_3 = pd.read_csv('/content/drive/MyDrive/hw2_data-1/hw2_2_X_3.csv', encoding='utf-8')
y_3 = pd.read_csv('/content/drive/MyDrive/hw2_data-1/hw2_2_y_3.csv', encoding='utf-8')

# %%
X_3.head()
# Out:
#    4.65115066e+00  2.50149720e+00
# 0        0.678305        0.372280
# 1       -0.527084        5.236776
# 2       -0.089073        1.926832
# 3        3.480903        1.277995
# 4        1.535065        2.460295

# %%
y_3.head()
# Out:
#    1
# 0  1
# 1 -1
# 2 -1
# 3  1
# 4 -1

# %%
#linear SVM with Softmargin
clf_3 = svm.SVC(kernel='linear', C = 1)
clf_3.fit(X_3, y_3)

#plot the data
res_3 = pd.concat([X_3, y_3], axis=1)
plt.scatter(res_3.iloc[:, 0],res_3.iloc[:, 1],c=res_3.iloc[:,2], s=30,cmap=plt.cm.Paired)

#초평면(Hyper-Plane) 표현
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf_3.decision_function(xy).reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1], alpha=0.5, linestyles=['--', '-', '--'])

# Support Vector 표현
ax.scatter(clf_3.support_vectors_[:,0], clf_3.support_vectors_[:,1], s=100, linewidth=2, facecolors='none', edgecolors='k')

plt.xlabel('X_3[:,0]')
plt.ylabel('X_3[:,1]')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"

# %%
#linear SVM with Softmargin
clf_3 = svm.SVC(kernel='linear', C = 0.1)
clf_3.fit(X_3, y_3)

#plot the data
res_3 = pd.concat([X_3, y_3], axis=1)
plt.scatter(res_3.iloc[:, 0],res_3.iloc[:, 1],c=res_3.iloc[:,2], s=30,cmap=plt.cm.Paired)

#초평면(Hyper-Plane) 표현
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf_3.decision_function(xy).reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1], alpha=0.5, linestyles=['--', '-', '--'])

# Support Vector 표현
ax.scatter(clf_3.support_vectors_[:,0], clf_3.support_vectors_[:,1], s=100, linewidth=2,facecolors='none',edgecolors='k')

plt.xlabel('X_3[:,0]')
plt.ylabel('X_3[:,1]')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"

# %%
#linear SVM with Softmargin
clf_3 = svm.SVC(kernel='linear', C = 0.01)
clf_3.fit(X_3, y_3)

#plot the data
res_3 = pd.concat([X_3, y_3], axis=1)
plt.scatter(res_3.iloc[:, 0],res_3.iloc[:, 1],c=res_3.iloc[:,2], s=30,cmap=plt.cm.Paired)

#초평면(Hyper-Plane) 표현
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = clf_3.decision_function(xy).reshape(XX.shape)
ax.contour(XX, YY, Z, colors='k', levels=[-1,0,1], alpha=0.5, linestyles=['--', '-', '--'])

# Support Vector 표현
ax.scatter(clf_3.support_vectors_[:,0], clf_3.support_vectors_[:,1], s=100, linewidth=2, facecolors='none', edgecolors='k')

plt.xlabel('X_3[:,0]')
plt.ylabel('X_3[:,1]')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"
